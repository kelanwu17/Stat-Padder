# %%
from nba_api.stats.static import teams, players
from nba_api.stats.endpoints import playerawards, commonplayerinfo,franchisehistory, TeamYearByYearStats, commonteamroster, commonteamyears, commonallplayers, playercareerstats, playergamelog, playergamelogs
import pandas as pd
import json
# nba_teams = teams.get_teams()
# rockets = [team for team in nba_teams if team['abbreviation'] == 'CLE'][0]
# rockets_id = rockets['id']

# print(rockets)
# print(f'rockets_id: {rockets_id}')

# %%
player_input = 'paolo banchero'
nba_players = json.loads(commonallplayers.CommonAllPlayers().get_normalized_json())
players = nba_players['CommonAllPlayers'][0]
player_id = 0;
player_name = ""

for i in range(0, len(nba_players['CommonAllPlayers'])):
    if nba_players['CommonAllPlayers'][i]['DISPLAY_FIRST_LAST'].lower() == player_input.lower():
        print(nba_players['CommonAllPlayers'][i])
        player_id = nba_players['CommonAllPlayers'][i]['PERSON_ID']
        player_name = nba_players['CommonAllPlayers'][i]['DISPLAY_FIRST_LAST']
        break
stats = json.loads(playercareerstats.PlayerCareerStats(player_id = player_id).get_normalized_json())
careerpts = 0
careergames = 0
careerptsavg = 0
careerassists = 0
careerrebounds = 0
for i in range(0, len(stats['SeasonTotalsRegularSeason'])):
    if stats['SeasonTotalsRegularSeason'][i]['GP'] > 0:
        careergames = careergames + stats['SeasonTotalsRegularSeason'][i]['GP']
    if stats['SeasonTotalsRegularSeason'][i]['PTS'] > 0:
        careerpts = careerpts + stats['SeasonTotalsRegularSeason'][i]['PTS']
    if stats['SeasonTotalsRegularSeason'][i]['REB'] > 0:
        careerrebounds = careerrebounds + stats['SeasonTotalsRegularSeason'][i]['REB']
    if stats['SeasonTotalsRegularSeason'][i]['AST'] > 0:
        careerassists = careerassists + stats['SeasonTotalsRegularSeason'][i]['AST']
print(stats['SeasonTotalsRegularSeason'])
print("Games Played ", careergames)
print("TOTAL POINTS ", careerpts)
careerptsavg = careerpts/careergames
print("CAREER PTS AVG ", round(careerptsavg, 2))
print("Career Assists ", round(careerassists/careergames,2))
print("Career Reb ", round(careerrebounds/careergames,2))
# Out:
# {'PERSON_ID': 1631094, 'DISPLAY_LAST_COMMA_FIRST': 'Banchero, Paolo', 'DISPLAY_FIRST_LAST': 'Paolo Banchero', 'ROSTERSTATUS': 1, 'FROM_YEAR': '2022', 'TO_YEAR': '2022', 'PLAYERCODE': 'paolo_banchero', 'PLAYER_SLUG': 'paolo_banchero', 'TEAM_ID': 1610612753, 'TEAM_CITY': 'Orlando', 'TEAM_NAME': 'Magic', 'TEAM_ABBREVIATION': 'ORL', 'TEAM_CODE': 'magic', 'TEAM_SLUG': 'magic', 'GAMES_PLAYED_FLAG': 'Y', 'OTHERLEAGUE_EXPERIENCE_CH': '00'}
# [{'PLAYER_ID': 1631094, 'SEASON_ID': '2022-23', 'LEAGUE_ID': '00', 'TEAM_ID': 1610612753, 'TEAM_ABBREVIATION': 'ORL', 'PLAYER_AGE': 19.0, 'GP': 8, 'GS': 8, 'MIN': 270.0, 'FGM': 59, 'FGA': 134, 'FG_PCT': 0.44, 'FG3M': 9, 'FG3A': 32, 'FG3_PCT': 0.281, 'FTM': 47, 'FTA': 63, 'FT_PCT': 0.746, 'OREB': 8, 'DREB': 53, 'REB': 61, 'AST': 29, 'STL': 5, 'BLK': 8, 'TOV': 22, 'PF': 16, 'PTS': 174}]
# Games Played  8
# TOTAL POINTS  174
# CAREER PTS AVG  21.75
# Career Assists  3.62
# Career Reb  7.62

# %%
player_awards = playerawards.PlayerAwards(player_id = player_id)
player_json = player_awards.get_normalized_json()
player_json_loads = json.loads(player_json)
print(json.dumps(player_json_loads, indent = 4))
all_defense_team = 0
all_nba = 0
fmvp = 0
mvp = 0
roty = 0
for i in range(0,len(player_json_loads["PlayerAwards"])):
    if (player_json_loads["PlayerAwards"][i]['DESCRIPTION'] == "All-Defensive Team"):
        all_defense_team += 1
    elif (player_json_loads["PlayerAwards"][i]['DESCRIPTION'] == "All-NBA"):
        all_nba += 1
    elif (player_json_loads["PlayerAwards"][i]['DESCRIPTION'] == "NBA Finals Most Valuable Player"):
        fmvp += 1
    elif (player_json_loads["PlayerAwards"][i]['DESCRIPTION'] == "NBA Most Valuable Player"):
        mvp += 1
    elif (player_json_loads["PlayerAwards"][i]['DESCRIPTION'] == "NBA Rookie of the Year"):
        roty += 1
print(all_defense_team, "x All_Defensive Team")
print(all_nba, "x All_NBA")
print(fmvp, "x Finals MVP")
print(mvp, "x MVP")
print(roty, "x Rookie of the Year")
# Out:
# {
#     "PlayerAwards": []
# }
# 0 x All_Defensive Team
# 0 x All_NBA
# 0 x Finals MVP
# 0 x MVP
# 0 x Rookie of the Year

# %%
player_info = json.loads((commonplayerinfo.CommonPlayerInfo(player_id = player_id)).get_normalized_json())
player_team = player_info["CommonPlayerInfo"][0]["TEAM_NAME"]
player_team_id = player_info["CommonPlayerInfo"][0]["TEAM_ID"]
player_country = player_info["CommonPlayerInfo"][0]["COUNTRY"]
player_season = player_info["AvailableSeasons"][0]["SEASON_ID"]
player_height = player_info["CommonPlayerInfo"][0]["HEIGHT"]
player_weight = player_info["CommonPlayerInfo"][0]["WEIGHT"]

print(player_info)
print(player_team)
print(player_team_id)
print(player_country)
print(player_season)
# Out:
# {'CommonPlayerInfo': [{'PERSON_ID': 1631094, 'FIRST_NAME': 'Paolo', 'LAST_NAME': 'Banchero', 'DISPLAY_FIRST_LAST': 'Paolo Banchero', 'DISPLAY_LAST_COMMA_FIRST': 'Banchero, Paolo', 'DISPLAY_FI_LAST': 'P. Banchero', 'PLAYER_SLUG': 'paolo-banchero', 'BIRTHDATE': '2002-11-12T00:00:00', 'SCHOOL': 'Duke', 'COUNTRY': 'USA', 'LAST_AFFILIATION': 'Duke/USA', 'HEIGHT': '6-10', 'WEIGHT': '250', 'SEASON_EXP': 0, 'JERSEY': '5', 'POSITION': 'Forward', 'ROSTERSTATUS': 'Active', 'GAMES_PLAYED_CURRENT_SEASON_FLAG': 'Y', 'TEAM_ID': 1610612753, 'TEAM_NAME': 'Magic', 'TEAM_ABBREVIATION': 'ORL', 'TEAM_CODE': 'magic', 'TEAM_CITY': 'Orlando', 'PLAYERCODE': 'paolo_banchero', 'FROM_YEAR': 2022, 'TO_YEAR': 2022, 'DLEAGUE_FLAG': 'N', 'NBA_FLAG': 'Y', 'GAMES_PLAYED_FLAG': 'Y', 'DRAFT_YEAR': '2022', 'DRAFT_ROUND': '1', 'DRAFT_NUMBER': '1', 'GREATEST_75_FLAG': 'N'}], 'PlayerHeadlineStats': [{'PLAYER_ID': 1631094, 'PLAYER_NAME': 'Paolo Banchero', 'TimeFrame': '2022-23', 'PTS': 21.8, 'AST': 3.6, 'REB': 7.6, 'PIE': 0.142}], 'AvailableSeasons': [{'SEASON_ID': '12022'}, {'SEASON_ID': '22022'}]}
# Magic
# 1610612753
# USA
# 12022

# %%
game_logs = json.loads(playergamelog.PlayerGameLog(player_id = player_id).get_normalized_json())
games = 0
print(len(game_logs['PlayerGameLog']))
print(games) 
print(game_logs)

game_date = []
match = []
log_pts = []
log_fg = []
log_three = []
log_ft=[]
log_oreb=[]
log_dreb=[]
log_ast=[]
log_stl=[]
log_blk=[]
log_tov=[]
log_pm = []
log_min = []

for i in range(0,5):
    game_date.append(game_logs['PlayerGameLog'][i]['GAME_DATE'])
    match.append(game_logs['PlayerGameLog'][i]['MATCHUP'])
    log_pts.append(game_logs['PlayerGameLog'][i]['PTS'])
    log_fg.append(str(game_logs['PlayerGameLog'][i]['FGM']) + "/" + str(game_logs['PlayerGameLog'][i]['FGA']))
    log_three.append(str(game_logs['PlayerGameLog'][i]['FG3M']) + "/" + str(game_logs['PlayerGameLog'][i]['FG3A']))
    log_ft.append(str(game_logs['PlayerGameLog'][i]['FTM']) + "/" + str(game_logs['PlayerGameLog'][i]['FTA']))
    log_oreb.append(game_logs['PlayerGameLog'][i]['OREB'])
    log_dreb.append(game_logs['PlayerGameLog'][i]['DREB'])
    log_ast.append(game_logs['PlayerGameLog'][i]['AST'])
    log_stl.append(game_logs['PlayerGameLog'][i]['STL'])
    log_blk.append(game_logs['PlayerGameLog'][i]['BLK'])
    log_tov.append(game_logs['PlayerGameLog'][i]['TOV'])
    log_pm.append(game_logs['PlayerGameLog'][i]['PLUS_MINUS'])
    log_min.append(game_logs['PlayerGameLog'][i]['MIN'])

print(log_min)
# Out:
# 8
# 0
# {'PlayerGameLog': [{'SEASON_ID': '22022', 'Player_ID': 1631094, 'Game_ID': '0022200105', 'GAME_DATE': 'NOV 01, 2022', 'MATCHUP': 'ORL @ OKC', 'WL': 'L', 'MIN': 37, 'FGM': 6, 'FGA': 13, 'FG_PCT': 0.462, 'FG3M': 0, 'FG3A': 1, 'FG3_PCT': 0.0, 'FTM': 3, 'FTA': 3, 'FT_PCT': 1.0, 'OREB': 0, 'DREB': 8, 'REB': 8, 'AST': 2, 'STL': 1, 'BLK': 0, 'TOV': 4, 'PF': 0, 'PTS': 15, 'PLUS_MINUS': 1, 'VIDEO_AVAILABLE': 1}, {'SEASON_ID': '22022', 'Player_ID': 1631094, 'Game_ID': '0022200093', 'GAME_DATE': 'OCT 30, 2022', 'MATCHUP': 'ORL @ DAL', 'WL': 'L', 'MIN': 32, 'FGM': 6, 'FGA': 20, 'FG_PCT': 0.3, 'FG3M': 1, 'FG3A': 6, 'FG3_PCT': 0.167, 'FTM': 5, 'FTA': 8, 'FT_PCT': 0.625, 'OREB': 0, 'DREB': 3, 'REB': 3, 'AST': 4, 'STL': 0, 'BLK': 0, 'TOV': 2, 'PF': 4, 'PTS': 18, 'PLUS_MINUS': 6, 'VIDEO_AVAILABLE': 1}, {'SEASON_ID': '22022', 'Player_ID': 1631094, 'Game_ID': '0022200071', 'GAME_DATE': 'OCT 28, 2022', 'MATCHUP': 'ORL vs. CHA', 'WL': 'W', 'MIN': 27, 'FGM': 8, 'FGA': 14, 'FG_PCT': 0.571, 'FG3M': 2, 'FG3A': 4, 'FG3_PCT': 0.5, 'FTM': 3, 'FTA': 7, 'FT_PCT': 0.429, 'OREB': 2, 'DREB': 10, 'REB': 12, 'AST': 7, 'STL': 0, 'BLK': 0, 'TOV': 2, 'PF': 0, 'PTS': 21, 'PLUS_MINUS': 27, 'VIDEO_AVAILABLE': 1}, {'SEASON_ID': '22022', 'Player_ID': 1631094, 'Game_ID': '0022200056', 'GAME_DATE': 'OCT 26, 2022', 'MATCHUP': 'ORL @ CLE', 'WL': 'L', 'MIN': 37, 'FGM': 10, 'FGA': 19, 'FG_PCT': 0.526, 'FG3M': 3, 'FG3A': 5, 'FG3_PCT': 0.6, 'FTM': 6, 'FTA': 8, 'FT_PCT': 0.75, 'OREB': 1, 'DREB': 7, 'REB': 8, 'AST': 4, 'STL': 1, 'BLK': 2, 'TOV': 3, 'PF': 2, 'PTS': 29, 'PLUS_MINUS': -7, 'VIDEO_AVAILABLE': 1}, {'SEASON_ID': '22022', 'Player_ID': 1631094, 'Game_ID': '0022200046', 'GAME_DATE': 'OCT 24, 2022', 'MATCHUP': 'ORL @ NYK', 'WL': 'L', 'MIN': 34, 'FGM': 6, 'FGA': 13, 'FG_PCT': 0.462, 'FG3M': 0, 'FG3A': 3, 'FG3_PCT': 0.0, 'FTM': 9, 'FTA': 11, 'FT_PCT': 0.818, 'OREB': 0, 'DREB': 4, 'REB': 4, 'AST': 2, 'STL': 2, 'BLK': 0, 'TOV': 1, 'PF': 3, 'PTS': 21, 'PLUS_MINUS': -2, 'VIDEO_AVAILABLE': 1}, {'SEASON_ID': '22022', 'Player_ID': 1631094, 'Game_ID': '0022200030', 'GAME_DATE': 'OCT 22, 2022', 'MATCHUP': 'ORL vs. BOS', 'WL': 'L', 'MIN': 33, 'FGM': 6, 'FGA': 19, 'FG_PCT': 0.316, 'FG3M': 2, 'FG3A': 7, 'FG3_PCT': 0.286, 'FTM': 9, 'FTA': 11, 'FT_PCT': 0.818, 'OREB': 1, 'DREB': 4, 'REB': 5, 'AST': 3, 'STL': 0, 'BLK': 1, 'TOV': 2, 'PF': 1, 'PTS': 23, 'PLUS_MINUS': -16, 'VIDEO_AVAILABLE': 1}, {'SEASON_ID': '22022', 'Player_ID': 1631094, 'Game_ID': '0022200020', 'GAME_DATE': 'OCT 21, 2022', 'MATCHUP': 'ORL @ ATL', 'WL': 'L', 'MIN': 34, 'FGM': 6, 'FGA': 18, 'FG_PCT': 0.333, 'FG3M': 1, 'FG3A': 6, 'FG3_PCT': 0.167, 'FTM': 7, 'FTA': 8, 'FT_PCT': 0.875, 'OREB': 2, 'DREB': 10, 'REB': 12, 'AST': 2, 'STL': 1, 'BLK': 3, 'TOV': 4, 'PF': 1, 'PTS': 20, 'PLUS_MINUS': -10, 'VIDEO_AVAILABLE': 1}, {'SEASON_ID': '22022', 'Player_ID': 1631094, 'Game_ID': '0022200003', 'GAME_DATE': 'OCT 19, 2022', 'MATCHUP': 'ORL @ DET', 'WL': 'L', 'MIN': 35, 'FGM': 11, 'FGA': 18, 'FG_PCT': 0.611, 'FG3M': 0, 'FG3A': 0, 'FG3_PCT': 0.0, 'FTM': 5, 'FTA': 7, 'FT_PCT': 0.714, 'OREB': 2, 'DREB': 7, 'REB': 9, 'AST': 5, 'STL': 0, 'BLK': 2, 'TOV': 4, 'PF': 5, 'PTS': 27, 'PLUS_MINUS': 2, 'VIDEO_AVAILABLE': 1}]}
# [37, 32, 27, 37, 34]

# %%
game_logs = json.loads(playergamelogs.PlayerGameLogs(player_id_nullable= player_id).get_normalized_json())
counter = 0
games_played = []
# for i in range(len(game_logs['PlayerGameLogs'])):
#      if game_logs['PlayerGameLogs'][i]['PLAYER_ID'] == player_id:
#          games_played.append(game_logs['PlayerGameLogs'][i]['SEASON_YEAR'])
# print(games_played)
print(game_logs['PlayerGameLogs'])
# Out:
# []
